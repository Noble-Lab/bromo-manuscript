# %%
from bromo.evaluations.tka import eval_curve_list
from bromo.evaluations.utils import prepare_dfs, avg_fwdrev_score

# %% [markdown]
# ### 1. TKA plots for: yeast-lumos

# %%
scratch_preds_path_lumos = '../../Datasets/finetuning/yeast-lumos/trainedfromscratch/testset_predictions.tsv'
finetuned_preds_path_lumos = '../../Datasets/finetuning/yeast-lumos/finetuned/testset_predictions.tsv'
pretrained_preds_path_lumos = '../../Datasets/finetuning/yeast-lumos/pretrained/testset_predictions.tsv'
scratch_preds_lumos = prepare_dfs(scratch_preds_path_lumos)
finetuned_preds_lumos = prepare_dfs(finetuned_preds_path_lumos)
pretrained_preds_lumos = prepare_dfs(pretrained_preds_path_lumos)


scratch_uniquepair_lumos = avg_fwdrev_score(scratch_preds_lumos)
finetuned_uniquepair_lumos = avg_fwdrev_score(finetuned_preds_lumos)
pretrained_uniquepair_lumos = avg_fwdrev_score(pretrained_preds_lumos)

# %%
curve_dicts_q1_lumos = eval_curve_list(
    [finetuned_uniquepair_lumos,scratch_uniquepair_lumos,pretrained_uniquepair_lumos], 
    topk=5, metric="q1", labels=['Finetuned','TrainedFromScratch','Pretrained'],
    title = 'yeast-lumos',
    save_path = './Fig4e_lumos_yeast.pdf',
    ttest_loc = (0.35, 0.37),
    ylim = (0.25, 0.7),
    legend_loc = (0.01, 0.72),
    figsize = (4,4),
    legend_fs = 12,
    colors = ["#009E73","#CC79A7","#0072B2"],
    error_bars = True,
    band='sem')

# %% [markdown]
# ### 2. TKA plots for: yeast-exploris

# %%
scratch_preds_path_exploris = '../../Datasets/finetuning/yeast-exploris/trainedfromscratch/testset_predictions.tsv'
finetuned_preds_path_exploris = '../../Datasets/finetuning/yeast-exploris/finetuned/testset_predictions.tsv'
pretrained_preds_path_exploris = '../../Datasets/finetuning/yeast-exploris/pretrained/testset_predictions.tsv'
scratch_preds_exploris = prepare_dfs(scratch_preds_path_exploris)
finetuned_preds_exploris = prepare_dfs(finetuned_preds_path_exploris)
pretrained_preds_exploris= prepare_dfs(pretrained_preds_path_exploris)

scratch_uniquepair_exploris = avg_fwdrev_score(scratch_preds_exploris)
finetuned_uniquepair_exploris = avg_fwdrev_score(finetuned_preds_exploris)
pretrained_uniquepair_exploris = avg_fwdrev_score(pretrained_preds_exploris)

# %%
curve_dicts_q1_exploris = eval_curve_list(
    [finetuned_uniquepair_exploris,scratch_uniquepair_exploris,pretrained_uniquepair_exploris], 
    topk=5, metric="q1", labels=['Finetuned','TrainedFromScratch','Pretrained'],
    title = 'yeast-exploris',
    save_path = './Fig4b_exploris_yeast.pdf',
    ttest_loc = (0.35, 0.37),
    ylim = (0.25, 0.7),
    figsize = (4,4),
    legend_loc = (0.01, 0.72),
    legend_fs = 12,
    colors = ["#009E73","#CC79A7","#0072B2"],
    error_bars = True,
    band='sem')

# %% [markdown]
# ### 3. TKA plots for: human-exploris

# %%
scratch_preds_path_exploris = '../../Datasets/finetuning/human-exploris/trainedfromscratch/testset_predictions.tsv'
finetuned_preds_path_exploris = '../../Datasets/finetuning/human-exploris/finetuned/testset_predictions.tsv'
pretrained_preds_path_exploris = '../../Datasets/finetuning/human-exploris/pretrained/testset_predictions.tsv'
scratch_preds_exploris = prepare_dfs(scratch_preds_path_exploris)
finetuned_preds_exploris = prepare_dfs(finetuned_preds_path_exploris)
pretrained_preds_exploris= prepare_dfs(pretrained_preds_path_exploris)

scratch_uniquepair_exploris = avg_fwdrev_score(scratch_preds_exploris)
finetuned_uniquepair_exploris = avg_fwdrev_score(finetuned_preds_exploris)
pretrained_uniquepair_exploris = avg_fwdrev_score(pretrained_preds_exploris)

# %%
curve_dicts_q1_exploris = eval_curve_list(
    [finetuned_uniquepair_exploris,scratch_uniquepair_exploris,pretrained_uniquepair_exploris], 
    topk=5, metric="q1", labels=['Finetuned','TrainedFromScratch','Pretrained'],
    title = 'human-exploris',
    save_path = './Fig4a_exploris_human.pdf',
    ttest_loc = (0.35, 0.37),
    figsize = (4,4),
    ylim = (0.25, 0.7),
    legend_loc = (0.01, 0.72),
    legend_fs = 12,
    colors = ["#009E73","#CC79A7","#0072B2"],
    error_bars = True,
    band='sem')

# %% [markdown]
# ### 4. TKA plots for: human-lumos

# %%
scratch_preds_path_lumos = '../../Datasets/finetuning/human-lumos/trainedfromscratch/testset_predictions.tsv'
finetuned_preds_path_lumos = '../../Datasets/finetuning/human-lumos/finetuned/testset_predictions.tsv'
pretrained_preds_path_lumos = '../../Datasets/finetuning/human-lumos/pretrained/testset_predictions.tsv'
scratch_preds_lumos = prepare_dfs(scratch_preds_path_lumos)
finetuned_preds_lumos = prepare_dfs(finetuned_preds_path_lumos)
pretrained_preds_lumos = prepare_dfs(pretrained_preds_path_lumos)

scratch_uniquepair_lumos = avg_fwdrev_score(scratch_preds_lumos)
finetuned_uniquepair_lumos = avg_fwdrev_score(finetuned_preds_lumos)
pretrained_uniquepair_lumos = avg_fwdrev_score(pretrained_preds_lumos)

# %%
curve_dicts_q1_lumos = eval_curve_list(
    [finetuned_uniquepair_lumos,scratch_uniquepair_lumos,pretrained_uniquepair_lumos], 
    topk=5, metric="q1", labels=['Finetuned','TrainedFromScratch','Pretrained'],
    title = 'human-lumos',
    save_path = './Fig4d_lumos_human.pdf',
    ttest_loc = (0.35, 0.37),
    ylim = (0.25, 0.7),
    figsize = (4,4),
    legend_loc = (0.01, 0.72),
    legend_fs = 12,
    colors = ["#009E73","#CC79A7","#0072B2"],
    error_bars = True,
    band='sem')

# %% [markdown]
# ### 5. TKA plots for: human-pan

# %%
scratch_preds_path_cancer = '../../Datasets/finetuning/human-pan/trainedfromscratch/testset_predictions.tsv'
finetuned_preds_path_cancer = '../../Datasets/finetuning/human-pan/finetuned/testset_predictions.tsv'
pretrained_preds_path_cancer = '../../Datasets/finetuning/human-pan/pretrained/testset_predictions.tsv'
scratch_preds_cancer = prepare_dfs(scratch_preds_path_cancer)
finetuned_preds_cancer = prepare_dfs(finetuned_preds_path_cancer)
pretrained_preds_cancer = prepare_dfs(pretrained_preds_path_cancer)

scratch_uniquepair_cancer = avg_fwdrev_score(scratch_preds_cancer)
finetuned_uniquepair_cancer = avg_fwdrev_score(finetuned_preds_cancer)
pretrained_uniquepair_cancer = avg_fwdrev_score(pretrained_preds_cancer)

# %%
curve_dicts_q1_cancer = eval_curve_list(
    [finetuned_uniquepair_cancer,scratch_uniquepair_cancer,pretrained_uniquepair_cancer], 
    topk=5, metric="q1", labels=['Finetuned','TrainedFromScratch','Pretrained'],
    title = 'human-pan',
    save_path = './Fig4c_humanpan.pdf',
    ttest_loc = (0.35, 0.37),
    ylim = (0.25, 0.7),
    figsize = (4,4),
    legend_loc = (0.01, 0.72),
    legend_fs = 12,
    colors = ["#009E73","#CC79A7","#0072B2"],
    error_bars = True,
    band='sem')
